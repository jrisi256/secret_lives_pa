# %%
import sys
print(sys.version)
# Out:
# 3.13.3 (tags/v3.13.3:6280bb5, Apr  8 2025, 14:47:33) [MSC v.1943 64 bit (AMD64)]

# %%
# %load_ext rich
from ipywidgets import interact
import io
import itertools
import os
import glob
import pandas as pd


from docket_extract import *

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Ashley Rodriguez\OneDrive - The Pennsylvania State University\SecretLives\Ashley's Folder\share with Joe

# %%
ds_dir = "C:/Users/Ashley Rodriguez/OneDrive - The Pennsylvania State University/SecretLives/Ashley's Folder/share with Joe/Example Docket and Court Summary Files"
files_in_dir = os.listdir(ds_dir)

for f in files_in_dir:
    print(f)
# Out:
# DS_Allegheny_CP_02_CR_0013359_2006.pdf
# DS_Allegheny_CP_02_CR_0013433_2019.pdf
# DS_Allegheny_CP_02_CR_0015427_2006.pdf
# DS_Blair_CP_07_CR_0000189_2023.pdf
# DS_Centre_CP_14_CR_0001606_2014.pdf
# DS_Dauphin_CP_22_CR_0004405_2023.pdf
# DS_Erie_CP-25-CR-0002821-2005.pdf
# DS_Erie_CP_25_CR_0002762_2010.pdf
# DS_Montgomery_CP_46_CR_0003606_2010.pdf

# %%
#ds_dir = "../../Example Docket and Court Summary Files/"
fnames = list(sorted(glob.glob(os.path.join(ds_dir, "*DS_*.pdf"))))
fnames
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     "C:/Users/Ashley Rodriguez/OneDrive - The Pennsylvania State University/SecretLives/Ashley's Folder/share with Joe/Example Docket and Court Summary Files\\DS_Allegheny_CP_02_CR_0013359_2006.pdf",
#     "C:/Users/Ashley Rodriguez/OneDrive - The Pennsylvania State University/SecretLives/Ashley's Folder/share with Joe/Example Docket and Court Summary Files\\DS_Allegheny_CP_02_CR_0013433_2019.pdf",
#     "C:/Users/Ashley Rodriguez/OneDrive - The Pennsylvania State University/SecretLives/Ashley's Folder/share with Joe/Example Docket and Court Summary Files\\DS_Allegheny_CP_02_CR_0015427_2006.pdf",
#     "C:/Users/Ashley Rodriguez/OneDrive - The Pennsylvania State University/SecretLives/Ashley's Folder/share with Joe/Example Docket and Court Summary Files\\DS_Blair_CP_07_CR_0000189_2023.pdf",
#     "C:/Users/Ashley Rodriguez/OneDrive - The Pennsylvania State University/SecretLives/Ashley's Folder/share with Joe/Example Docket and Court Summary Files\\DS_Centre_CP_14_CR_0001606_2014.pdf",
#     "C:/Users/Ashley Rodriguez/OneDrive - The Pennsylvania State University/SecretLives/Ashley's Folder/share with Joe/Example Docket and Court Summary Files\\DS_Dauphin_CP_22_CR_0004405_2023.pdf",
#     "C:/Users/Ashley Rodriguez/OneDrive - The Pennsylvania State University/SecretLives/Ashley's Folder/share with Joe/Example Docket and Court Summary Files\\DS_Erie_CP-25-CR-0002821-2005.pdf",
#     "C:/Users/Ashley Rodriguez/OneDrive - The Pennsylvania State University/SecretLives/Ashley's Folder/share with Joe/Example Docket and Court Summary Files\\DS_Erie_CP_25_CR_0002762_2010.pdf",
#     "C:/Users/Ashley Rodriguez/OneDrive - The Pennsylvania State University/SecretLives/Ashley's Folder/share with Joe/Example Docket and Court Summary Files\\DS_Montgomery_CP_46_CR_0003606_2010.pdf"
# ]

# %%
sectioned = {fname: extract_sections(extract_text_from_pdf(fname)) for fname in fnames}

# %%
all_keys = set(itertools.chain(*[list(d.keys()) for d in sectioned.values()]))
key_count = {k: sum([k in d for d in sectioned.values()]) for k in all_keys}
list(sorted(key_count.items(), key=lambda x: x[1], reverse=True))
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     ('BAIL', 9),
#     ('CASE PARTICIPANTS', 9),
#     ('CASE FINANCIAL INFORMATION', 9),
#     ('DEFENDANT INFORMATION', 9),
#     ('ENTRIES', 9),
#     ('CASE INFORMATION', 9),
#     ('DISPOSITION SENTENCING/PENALTIES', 9),
#     ('CRIMINAL DOCKET', 9),
#     ('ATTORNEY INFORMATION', 9),
#     ('CHARGES', 9),
#     ('STATUS INFORMATION', 9),
#     ('CALENDAR EVENTS', 8),
#     (
#         'COURT OF COMMON PLEAS OF ALLEGHENY COUNTY                           \n                                       DOCKET',
#         3
#     ),
#     ('PAYMENT PLAN SUMMARY', 2),
#     (
#         'COURT OF COMMON PLEAS OF ERIE COUNTY                            \n                                       DOCKET',
#         2
#     ),
#     ('RELATED CASES', 2),
#     (
#         'COURT OF COMMON PLEAS OF CENTRE COUNTY                            \n                                       DOCKET',
#         1
#     ),
#     ('CONFINEMENT INFORMATION', 1),
#     (
#         'COURT OF COMMON PLEAS OF BLAIR COUNTY                            \n                                       DOCKET',
#         1
#     ),
#     (
#         'COURT OF COMMON PLEAS OF MONTGOMERY COUNTY                           \n                                       DOCKET',
#         1
#     ),
#     (
#         'COURT OF COMMON PLEAS OF DAUPHIN COUNTY                           \n                                       DOCKET',
#         1
#     )
# ]

# %%
replacements = {
    "DISPOSITION SENTENCING/PENALTIES": "DISPOSITION / SENTENCING DETAILS"
    }
remove_keys = [""]
for fname, sdict in sectioned.items():
    for replace_source, replace_target in replacements.items():
        if replace_source in sdict:
            sdict[replace_target] = sdict.pop(replace_source)
    for k in remove_keys:
        if k in sdict:
            sdict.pop(k)
all_keys = set(itertools.chain(*[list(d.keys()) for d in sectioned.values()]))
key_count = {k: sum([k in d for d in sectioned.values()]) for k in all_keys}
list(sorted(key_count.items(), key=lambda x: x[1], reverse=True))
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     ('BAIL', 9),
#     ('CASE PARTICIPANTS', 9),
#     ('CASE FINANCIAL INFORMATION', 9),
#     ('DEFENDANT INFORMATION', 9),
#     ('ENTRIES', 9),
#     ('CASE INFORMATION', 9),
#     ('DISPOSITION / SENTENCING DETAILS', 9),
#     ('CRIMINAL DOCKET', 9),
#     ('ATTORNEY INFORMATION', 9),
#     ('CHARGES', 9),
#     ('STATUS INFORMATION', 9),
#     ('CALENDAR EVENTS', 8),
#     (
#         'COURT OF COMMON PLEAS OF ALLEGHENY COUNTY                           \n                                       DOCKET',
#         3
#     ),
#     ('PAYMENT PLAN SUMMARY', 2),
#     (
#         'COURT OF COMMON PLEAS OF ERIE COUNTY                            \n                                       DOCKET',
#         2
#     ),
#     ('RELATED CASES', 2),
#     (
#         'COURT OF COMMON PLEAS OF CENTRE COUNTY                            \n                                       DOCKET',
#         1
#     ),
#     ('CONFINEMENT INFORMATION', 1),
#     (
#         'COURT OF COMMON PLEAS OF BLAIR COUNTY                            \n                                       DOCKET',
#         1
#     ),
#     (
#         'COURT OF COMMON PLEAS OF MONTGOMERY COUNTY                           \n                                       DOCKET',
#         1
#     ),
#     (
#         'COURT OF COMMON PLEAS OF DAUPHIN COUNTY                           \n                                       DOCKET',
#         1
#     )
# ]

# %%
[print(sectioned[fname]["DEFENDANT INFORMATION"]) for fname in fnames]
# Out:
# Date Of Birth:  12/25/1961 City/State/Zip:
#
# Date Of Birth:  06/16/1981 City/State/Zip:
#
#
#
#
#      CPCMS 9082                                                         Printed:  03/21/2025
#            Recent entries made in the court filing offices may not be immediately reflected on these docket sheets. Neither the courts of the Unified Judicial
#           System of the Commonwealth of Pennsylvania nor the Administrative Office of Pennsylvania Courts assume any liability for inaccurate or delayed
#           data, errors or omissions on these reports.  Docket Sheet information should not be used in place of a criminal history background check which can
#           only be provided by the Pennsylvania State Police.  Moreover an employer who does not comply with the provisions of the Criminal History Record
#                         Information Act may be subject to civil liability as set forth in 18 Pa.C.S. Section 9183.
#
# Date Of Birth:  06/11/1986 City/State/Zip:  New kensington, PA  15068
#
# Date Of Birth:  11/03/1982 City/State/Zip:  Tyrone, PA  16686
#
# Date Of Birth:  08/07/1994 City/State/Zip:  Bellefonte, PA  16823
#
# Date Of Birth:  06/20/1967 City/State/Zip:  Harrisburg, PA  17104
#
# Date Of Birth:  10/24/1956 City/State/Zip:  Conneaut, OH  44030
#
# Date Of Birth:  01/15/1980 City/State/Zip:  Erie, PA  16502
#
# Date Of Birth:  01/22/1985 City/State/Zip:  Horsham, PA  19044
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [None, None, None, None, None, None, None, None, None]

# %%
[extract_defendant_information(sectioned[fname]["DEFENDANT INFORMATION"]) for fname in fnames]

# %%
sectioned[fnames[1]]["DEFENDANT INFORMATION"]

# %%
[print(sectioned[fname]["CASE INFORMATION"]) for fname in fnames]

# %%
[extract_case_information(sectioned[fname]["CASE INFORMATION"]) for fname in fnames]

# %%
sectioned[fnames[1]]["CASE INFORMATION"]

# %%
for fname in fnames:
    print(fname)
    print(sectioned[fname]["CHARGES"]) 
    print()

# %%
import re

for fname in fnames:
    if "Statute" in sectioned[fname]["CHARGES"]:
        charges_df = extract_charges_MC(sectioned[fname]["CHARGES"])
        print(fname) 
        print(charges_df)
        print()

# %%
[print(sectioned[fname]["STATUS INFORMATION"]) for fname in fnames]

# %%
# Example usage
text = """Case Status    Closed
    Status Date Processing Status                                    
    07/30/2020 Case Transferred to Court of Common Pleas             
    07/23/2020 Completed                                             
    07/23/2020 Case Balance Due                                      
    07/23/2020 Completed                                             
    04/02/2020 Awaiting Preliminary Hearing                          
    04/02/2020 Awaiting Preliminary Arraignment"""

case_status, status_df = extract_status_information(text)
print(case_status)
print(status_df)

# Additional example usage
text = """Case Status    Status Date Processing Status                                    
    Closed         06/04/2015 Case Transferred to Court of Common Pleas             
                   06/02/2015 Completed                                             
                   04/14/2015 Awaiting Preliminary Hearing"""

case_status, status_df = extract_status_information(text)
print(case_status)
print(status_df)

# %%
for fname in fnames:
    print(fname)
    print(extract_status_information(sectioned[fname]["STATUS INFORMATION"]))
    print()

# %%
for fname in fnames:
    print(fname)
    print(extract_status_information(sectioned[fname]["CASE FINANCIAL INFORMATION"]))
    print()

# %%
key = "CALENDAR EVENTS"
[print(sectioned[fname][key]) for fname in fnames]

# %%
# Example usage
text = """Case Calendar  Schedule  Start Room       Judge Name          Schedule        
      Event Type    Start Date Time                                 Status          
      Preliminary   08/27/2020  5:58 pm B08                         Scheduled       
      Arraignment                                                                   
      Status        10/14/2020 10:00 am 404     Judge Patrick F. Dugan Scheduled    
      Status        12/02/2020  9:00 am 200                         Cancelled       
      Trial         09/16/2021 11:30 am 606     Judge David H. Conroy Continued     
      Trial         12/10/2021 10:00 am 405     Judge David H. Conroy Scheduled"""

events_df = extract_calendar_events(text)
print(events_df)

# %%
for fname in fnames:
    print(fname)
    print(extract_calendar_events(sectioned[fname][key]))
    print()

# %%
key = "CASE PARTICIPANTS"
[print(sectioned[fname][key]) for fname in fnames]

# %%
defendants = {}
for fname in fnames:
    print(fname)
    participants = extract_case_participants(sectioned[fname][key])
    print(participants)
    defend_row = participants[participants["role"].str.contains("Defendant")]["name"]
    if len(defend_row) > 0:
        defendants[fname] = defend_row.values[0]
    else:
        defendants[fname] = ""
    print()

# %%
key = "DOCKET ENTRY INFORMATION"
[print(sectioned[fname][key]) for fname in fnames if key in sectioned[fname]]

# %%
for fname in fnames:
    print(fname)
    if key in sectioned[fname]:
        docket_entry = extract_docket_entry(sectioned[fname][key], defendants[fname])
        print(docket_entry)

# %%
key = "ATTORNEY INFORMATION"
[print(sectioned[fname][key] + "\n***\n") for fname in fnames if key in sectioned[fname]]

# %%
for fname in fnames:
    if key in sectioned[fname]:
        print(fname)
        print(sectioned[fname][key])
        print()
        attornies = extract_attorney_information(sectioned[fname][key])
        print(attornies)
        print()
        print("***")
        print()

# %%
key = "BAIL"
[print(sectioned[fname][key] + "\n***\n") for fname in fnames if key in sectioned[fname]]

# %%
for fname in fnames:
    if key in sectioned[fname]:
        print(fname)
        print(sectioned[fname][key])
        print()
        bail_info = extract_bail(sectioned[fname][key])
        print(bail_info)
        print()
        print("***")
        print()

# %%
[print(sectioned[fname]["DISPOSITION / SENTENCING DETAILS"]) for fname in fnames]
# Out:
# Disposition
#       Case Event                      Disposition Date    Final Disposition
#        Sequence/Description             Offense Disposition  Grade Section
#         Sentencing Judge                 Sentence Date        Credit For Time Served
#           Sentence/Diversion Program Type Incarceration/Diversionary Period Start Date
#             Sentence Conditions
#      Lower Court Proceeding (generic)
#       Lower Court Disposition         09/05/2006          Not Final
#        1 / Bad Checks                   Waived for Court (Lower Court) M3 18 § 4105 §§ A1*
#      Proceed to Court
#       Information Filed               11/21/2006          Not Final
#        1 / Bad Checks                   Proceed to Court     M3   18 § 4105 §§ A1*
#      Guilty Plea
#       ACT - Pre-Trial Conference      01/05/2007          Final Disposition
#        1 / Bad Checks                   Guilty Plea          M3   18 § 4105 §§ A1*
#         Durkin, Kathleen A.              01/08/2007
#           Probation                       Min of 6.00 Months
#                                           Max of 6.00 Months
#                                           6 months
#
#
#
#
#
#
#
#
#
#      CPCMS 9082                                                         Printed:  03/29/2025
#            Recent entries made in the court filing offices may not be immediately reflected on these docket sheets. Neither the courts of the Unified Judicial
#           System of the Commonwealth of Pennsylvania nor the Administrative Office of Pennsylvania Courts assume any liability for inaccurate or delayed
#           data, errors or omissions on these reports.  Docket Sheet information should not be used in place of a criminal history background check which can
#           only be provided by the Pennsylvania State Police.  Moreover an employer who does not comply with the provisions of the Criminal History Record
#                         Information Act may be subject to civil liability as set forth in 18 Pa.C.S. Section 9183.
#
# Disposition
#       Case Event                      Disposition Date    Final Disposition
#        Sequence/Description             Offense Disposition  Grade Section
#         Sentencing Judge                 Sentence Date        Credit For Time Served
#           Sentence/Diversion Program Type Incarceration/Diversionary Period Start Date
#             Sentence Conditions
#      Waived for Court (Lower Court)                    Defendant Was Present
#       Lower Court Disposition         11/27/2019          Not Final
#        1 / DUI: Highest Rte of Alc (BAC .16+) 1st Off  Waived for Court (Lower Court) M 75 § 3802 §§ C*
#        3 / Driv While Oper Priv Susp Or Revoked  Waived for Court (Lower Court) S 75 § 1543 §§ A
#      Proceed to Court                    Defendant Was Not Present
#       Information Filed               01/22/2020          Not Final
#        1 / DUI: Highest Rte of Alc (BAC .16+) 1st Off  Proceed to Court M 75 § 3802 §§ C*
#        3 / Driv While Oper Priv Susp Or Revoked  Proceed to Court S 75 § 1543 §§ A
#
#      Guilty Plea - Negotiated
#       Non-Jury Trial                  07/23/2020          Final Disposition
#        1 / DUI: Highest Rte of Alc (BAC .16+) 1st Off  Guilty Plea - Negotiated M 75 § 3802 §§ C*
#         Driscoll, John J.                09/21/2020           21 Days
#           Confinement                     Min of 3.00 Days      09/21/2020
#                                           Max of 6.00 Days
#                                           3-6 Days
#             Defendant is sentenced to time served and is to be paroled forthwith.
#           Probation                       Min of 6.00 Months    09/21/2020
#                                           Max of 6.00 Months
#                                           6 months
#             Receive a drug and alcohol evaluation.  Recieve drug screening.  Must attend Safe Driving School.
#             Defendant is to pay a $1,000.00 fine.
#      CPCMS 9082                                                         Printed:  03/21/2025
#            Recent entries made in the court filing offices may not be immediately reflected on these docket sheets. Neither the courts of the Unified Judicial
#           System of the Commonwealth of Pennsylvania nor the Administrative Office of Pennsylvania Courts assume any liability for inaccurate or delayed
#           data, errors or omissions on these reports.  Docket Sheet information should not be used in place of a criminal history background check which can
#           only be provided by the Pennsylvania State Police.  Moreover an employer who does not comply with the provisions of the Criminal History Record
#                         Information Act may be subject to civil liability as set forth in 18 Pa.C.S. Section 9183.
# Disposition
#       Case Event                      Disposition Date    Final Disposition
#        Sequence/Description             Offense Disposition  Grade Section
#         Sentencing Judge                 Sentence Date        Credit For Time Served
#           Sentence/Diversion Program Type Incarceration/Diversionary Period Start Date
#             Sentence Conditions
#             Costs are waived.
#        3 / Driv While Oper Priv Susp Or Revoked  Guilty Plea - Negotiated S 75 § 1543 §§ A
#         Driscoll, John J.                09/21/2020           21 Days
#           Confinement                     Min of 30.00 Days     09/21/2020
#                                           Max of 60.00 Days
#                                           Other
#             Defendant is permitted to serve sentence at SCI Fayette.
#             Defendant is to be paroled at minimum.
#             Defendant is to pay a $1,000.00 fine.
#       LINKED SENTENCES:
#        Link 1
#          CP-02-CR-0013433-2019 - Seq. No. 1 (75 § 3802 §§ C*) - Confinement is Concurrent with
#          CP-02-CR-0013433-2019 - Seq. No. 1 (75 § 3802 §§ C*) - Probation
#        Link 2
#          CP-02-CR-0013433-2019 - Seq. No. 1 (75 § 3802 §§ C*) - Confinement is Concurrent with
#          CP-02-CR-0013433-2019 - Seq. No. 3 (75 § 1543 §§ A) - Confinement
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      CPCMS 9082                                                         Printed:
2025
#            Recent entries made in the court filing offices may not be immediately reflected on these docket sheets. Neither the courts of the Unified Judicial
#           System of the Commonwealth of Pennsylvania nor the Administrative Office of Pennsylvania Courts assume any liability for inaccurate or delayed
#           data, errors or omissions on these reports.  Docket Sheet information should not be used in place of a criminal history background check which can
#           only be provided by the Pennsylvania State Police.  Moreover an employer who does not comply with the provisions of the Criminal History Record
#                         Information Act may be subject to civil liability as set forth in 18 Pa.C.S. Section 9183.
#
# Disposition
#       Case Event                      Disposition Date    Final Disposition
#        Sequence/Description             Offense Disposition  Grade Section
#         Sentencing Judge                 Sentence Date        Credit For Time Served
#           Sentence/Diversion Program Type Incarceration/Diversionary Period Start Date
#             Sentence Conditions
#      Waived for Court (Lower Court)                    Defendant Was Present
#       Lower Court Disposition         10/19/2023          Not Final
#      Proceed to Court                    Defendant Was Not Present
#       Information Filed               01/05/2024          Not Final
#        1 / Drg Lic Sus/Rev Purs to Sec 3802/1547B1-3rd or  Added by Information M3 75 § 1543 §§ B1iii
#        Subs. Violation
#      Guilty Plea
#       Plea Court                      05/28/2024          Final Disposition
#        1 / Drg Lic Sus/Rev Purs to Sec 3802/1547B1-3rd or  Guilty Plea M3 75 § 1543 §§ B1iii
#        Subs. Violation
#         Tully, William T.                05/28/2024
#           Confinement                     Min of 3.00 Months    05/28/2024
#                                           Max of 3.00 Months
#                                           Other
#           Probation                       Min of 12.00 Months   05/28/2024
#                                           Max of 12.00 Months
#                                           Other
#
#
#
#
#
#
#
#
#      CPCMS 9082                                                         Printed:  03/21/2025
#            Recent entries made in the court filing offices may not be immediately reflected on these docket sheets. Neither the courts of the Unified Judicial
#           System of the Commonwealth of Pennsylvania nor the Administrative Office of Pennsylvania Courts assume any liability for inaccurate or delayed
#           data, errors or omissions on these reports.  Docket Sheet information should not be used in place of a criminal history background check which can
#           only be provided by the Pennsylvania State Police.  Moreover an employer who does not comply with the provisions of the Criminal History Record
#                         Information Act may be subject to civil liability as set forth in 18 Pa.C.S. Section 9183.
#
# Disposition
#       Case Event                      Disposition Date    Final Disposition
#        Sequence/Description             Offense Disposition  Grade Section
#         Sentencing Judge                 Sentence Date        Credit For Time Served
#           Sentence/Diversion Program Type Incarceration/Diversionary Period Start Date
#             Sentence Conditions
#      Lower Court Proceeding (generic)
#       Lower Court Disposition         09/13/2005          Not Final
#        1 / DUI: Gen Imp/Inc of Driving Safely - 1st Off  Held for Court (Lower Court) M 75 § 3802 §§ A1*
#        2 / Signal Improp                Held for Court (Lower Court) S 75 § 3334 §§ B
#        3 / Improper Left Turn           Held for Court (Lower Court) S 75 § 3331 §§ B
#      ARD - County Open
#       ARD Court                       06/01/2006          Not Final
#        1 / DUI: Gen Imp/Inc of Driving Safely - 1st Off  ARD - County Open M 75 § 3802 §§ A1*
#         Domitrovich, Stephanie           06/01/2006
#           ARD - DUI                       12.00 Months          06/01/2006
#
#        2 / Signal Improp                ARD - County Open    S    75 § 3334 §§ B
#         Domitrovich, Stephanie           06/01/2006
#           ARD                                                   06/01/2006
#
#      CPCMS 9082                                                         Printed:  03/31/2025
#            Recent entries made in the court filing offices may not be immediately reflected on these docket sheets. Neither the courts of the Unified Judicial
#           System of the Commonwealth of Pennsylvania nor the Administrative Office of Pennsylvania Courts assume any liability for inaccurate or delayed
#           data, errors or omissions on these reports.  Docket Sheet information should not be used in place of a criminal history background check which can
#           only be provided by the Pennsylvania State Police.  Moreover an employer who does not comply with the provisions of the Criminal History Record
#                         Information Act may be subject to civil liability as set forth in 18 Pa.C.S. Section 9183.
# Disposition
#       Case Event                      Disposition Date    Final Disposition
#        Sequence/Description             Offense Disposition  Grade Section
#         Sentencing Judge                 Sentence Date        Credit For Time Served
#           Sentence/Diversion Program Type Incarceration/Diversionary Period Start Date
#             Sentence Conditions
#            fine & costs
#        3 / Improper Left Turn           ARD - County Open    S    75 § 3331 §§ B
#         Domitrovich, Stephanie           06/01/2006
#           ARD                                                   06/01/2006
#            fine & costs
#
# Disposition
#       Case Event                      Disposition Date    Final Disposition
#        Sequence/Description             Offense Disposition  Grade Section
#         Sentencing Judge                 Sentence Date        Credit For Time Served
#           Sentence/Diversion Program Type Incarceration/Diversionary Period Start Date
#             Sentence Conditions
#      Lower Court Proceeding (generic)
#       Lower Court Disposition         10/28/2010          Not Final
#        1 / Simple Assault               Waived for Court (Lower Court) M2 18 § 2701 §§ A
#        41 / Aggravated Assault          Charge Changed (Lower Court) F1 18 § 2702 §§ A1
#      Guilty Plea
#       Guilty Plea                     12/30/2010          Final Disposition
#        1 / Simple Assault               Guilty Plea          M2   18 § 2701 §§ A
#         DiSantis, Ernest J. Jr.          02/15/2011           162 Days
#           Confinement                     Min of 8.00 Months    02/15/2011
#                                           Max of 23.00 Months
#                                           Other
#        41 / Aggravated Assault          Charge Changed (Lower Court) F1 18 § 2702 §§ A1
#         DiSantis, Ernest J. Jr.          02/15/2011
#       LINKED SENTENCES:
#        Link 1
#          CP-25-CR-0002762-2010 - Seq. No. 1 (18§ 2701 §§ A) - Confinement is Concurrent with
#          Snyder County Docket - Snyder County Sentence
#
#
#
#
#
#
#
#
#      CPCMS 9082                                                         Printed:  04/03/2025
#            Recent entries made in the court filing offices may not be immediately reflected on these docket sheets. Neither the courts of the Unified Judicial
#           System of the Commonwealth of Pennsylvania nor the Administrative Office of Pennsylvania Courts assume any liability for inaccurate or delayed
#           data, errors or omissions on these reports.  Docket Sheet information should not be used in place of a criminal history background check which can
#           only be provided by the Pennsylvania State Police.  Moreover an employer who does not comply with the provisions of the Criminal History Record
#                         Information Act may be subject to civil liability as set forth in 18 Pa.C.S. Section 9183.
#
# Disposition
#       Case Event                      Disposition Date    Final Disposition
#        Sequence/Description             Offense Disposition  Grade Section
#         Sentencing Judge                 Sentence Date        Credit For Time Served
#           Sentence/Diversion Program Type Incarceration/Diversionary Period Start Date
#             Sentence Conditions
#      Lower Court Proceeding (generic)
#       Lower Court Disposition         05/24/2010          Not Final
#      Proceed to Court (Arraignment Waived)
#       Information Filed               07/13/2010          Not Final
#      Guilty Plea
#       Call of the Trial List          04/25/2011          Final Disposition
#        2 / Criminal Mischief - Damage Property  Guilty Plea  S    18 § 3304 §§ A5
#         Furber, William J. Jr.           04/25/2011
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      CPCMS 9082                                                         Printed:  03/23/2025
#            Recent entries made in the court filing offices may not be immediately reflected on these docket sheets. Neither the courts of the Unified Judicial
#           System of the Commonwealth of Pennsylvania nor the Administrative Office of Pennsylvania Courts assume any liability for inaccurate or delayed
#           data, errors or omissions on these reports.  Docket Sheet information should not be used in place of a criminal history background check which can
#           only be provided by the Pennsylvania State Police.  Moreover an employer who does not comply with the provisions of the Criminal History Record
#                         Information Act may be subject to civil liability as set forth in 18 Pa.C.S. Section 9183.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [None, None, None, None, None, None, None, None, None]

# %%
[extract_sentencing_disposition(sectioned[fname]["DISPOSITION / SENTENCING DETAILS"]) for fname in fnames]
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 [extract_sentencing_disposition(sectioned[fname]["DISPOSITION / SENTENCING DETAILS"]) fo     │
# │   2                                                                                              │
# │                                                                                                  │
# │ c:\Users\Ashley Rodriguez\OneDrive - The Pennsylvania State University\SecretLives\Ashley's      │
# │ Folder\share with Joe\docket_extract.py:333 in extract_sentencing_disposition                    │
# │                                                                                                  │
# │   330 │   │   re.MULTILINE,                                                                      │
# │   331 │   )                                                                                      │
# │   332 │   matches = pattern.findall(text)                                                        │
# │ ❱ 333 │   return pd.DataFrame(                                                                   │
# │   334 │   │   matches,                                                                           │
# │   335 │   │   columns=[                                                                          │
# │   336 │   │   │   "Disposition",                                                                 │
# │                                                                                                  │
# │ C:\Users\Ashley                                                                                  │
# │ Rodriguez\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:867 in __init__    │
# │                                                                                                  │
# │     864 │   │   │   │   │   │   typ=manager,                                                     │
# │     865 │   │   │   │   │   )                                                                    │
# │     866 │   │   │   │   else:                                                                    │
# │ ❱   867 │   │   │   │   │   mgr = ndarray_to_mgr(                                                │
# │     868 │   │   │   │   │   │   data,                                                            │
# │     869 │   │   │   │   │   │   index,                                                           │
# │     870 │   │   │   │   │   │   columns,                                                         │
# │                                                                                                  │
# │ C:\Users\Ashley                                                                                  │
# │ Rodriguez\AppData\Roaming\Python\Python313\site-packages\pandas\core\internals\construction.py:3 │
# │ 36 in ndarray_to_mgr                                                                             │
# │                                                                                                  │
# │    333 │   │   values.shape[0], values.shape[1], index=index, columns=columns                    │
# │    334 │   )                                                                                     │
# │    335 │                                                                                         │
# │ ❱  336 │   _check_values_indices_shape_match(values, index, columns)                             │
# │    337 │                                                                                         │
# │    338 │   if typ == "array":                                                                    │
# │    339 │   │   if issubclass(values.dtype.type, str):                                            │
# │                                                                                                  │
# │ C:\Users\Ashley                                                                                  │
# │ Rodriguez\AppData\Roaming\Python\Python313\site-packages\pandas\core\internals\construction.py:4 │
# │ 20 in _check_values_indices_shape_match                                                          │
# │                                                                                                  │
# │    417 │   │                                                                                     │
# │    418 │   │   passed = values.shape                                                             │
# │    419 │   │   implied = (len(index), len(columns))                                              │
# │ ❱  420 │   │   raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")  │
# │    421                                                                                           │
# │    422                                                                                           │
# │    423 def dict_to_mgr(                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: Shape of passed values is (3225, 1), indices imply (3225, 15)

# %%
[print(sectioned[fname]["PAYMENT PLAN SUMMARY"]) for fname in fnames]
